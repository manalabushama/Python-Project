# %% [markdown]
# # Import Classes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # declare and import Data

# %%
store=pd.read_csv('/content/Supermart Grocery Sales - Retail Analytics Dataset.csv')
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   Category       9994 non-null   object
#  3   Sub Category   9994 non-null   object
#  4   City           9994 non-null   object
#  5   Order Date     9994 non-null   object
#  6   Region         9994 non-null   object
#  7   Sales          9994 non-null   int64
#  8   Discount       9994 non-null   float64
#  9   Profit         9994 non-null   float64
#  10  State          9994 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 859.0+ KB

# %% [markdown]
# #Display columns

# %%
store.columns
# Out:
# Index(['Order ID', 'Customer Name', 'Category', 'Sub Category', 'City',
#        'Order Date', 'Region', 'Sales', 'Discount', 'Profit', 'State'],
#       dtype='object')

# %% [markdown]
# # Show Data

# %% [markdown]
# * display data

# %%
store
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#       Order Date Region  Sales  Discount  Profit       State
# 0     11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1     11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2     06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3     10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4     10-11-2016  South   2355      0.26  918.45  Tamil Nadu
# ...          ...    ...    ...       ...     ...         ...
# 9989  12/24/2015   West    945      0.16  359.10  Tamil Nadu
# 9990  07-12-2015   West   1195      0.26   71.70  Tamil Nadu
# 9991  06-06-2017   West   1567      0.16  501.44  Tamil Nadu
# 9992  10/16/2018   West   1659      0.15  597.24  Tamil Nadu
# 9993   4/17/2018   West   1034      0.28  165.44  Tamil Nadu
#
# [9994 rows x 11 columns]

# %% [markdown]
# * unique

# %%
store.nunique()
# Out:
# Order ID         9994
# Customer Name      50
# Category            7
# Sub Category       23
# City               24
# Order Date       1236
# Region              5
# Sales            1989
# Discount           26
# Profit           8380
# State               1
# dtype: int64

# %% [markdown]
# * check nulls

# %%
store.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %% [markdown]
# * Describe

# %%
store.describe().T
# Out:
#            count         mean         std     min        25%      50%  \
# Sales     9994.0  1496.596158  577.559036  500.00  1000.0000  1498.00
# Discount  9994.0     0.226817    0.074636    0.10     0.1600     0.23
# Profit    9994.0   374.937082  239.932881   25.25   180.0225   320.78
#
#                 75%      max
# Sales     1994.7500  2500.00
# Discount     0.2900     0.35
# Profit     525.6275  1120.95

# %%
store.describe(include='all').T
# Out:
#                 count unique            top  freq         mean         std  \
# Order ID         9994   9994            OD1     1          NaN         NaN
# Customer Name    9994     50         Amrish   227          NaN         NaN
# Category         9994      7         Snacks  1514          NaN         NaN
# Sub Category     9994     23  Health Drinks   719          NaN         NaN
# City             9994     24    Kanyakumari   459          NaN         NaN
# Order Date       9994   1236     09-05-2017    38          NaN         NaN
# Region           9994      5           West  3203          NaN         NaN
# Sales          9994.0    NaN            NaN   NaN  1496.596158  577.559036
# Discount       9994.0    NaN            NaN   NaN     0.226817    0.074636
# Profit         9994.0    NaN            NaN   NaN   374.937082  239.932881
# State            9994      1     Tamil Nadu  9994          NaN         NaN
#
#                  min       25%     50%       75%      max
# Order ID         NaN       NaN     NaN       NaN      NaN
# Customer Name    NaN       NaN     NaN       NaN      NaN
# Category         NaN       NaN     NaN       NaN      NaN
# Sub Category     NaN       NaN     NaN       NaN      NaN
# City             NaN       NaN     NaN       NaN      NaN
# Order Date       NaN       NaN     NaN       NaN      NaN
# Region           NaN       NaN     NaN       NaN      NaN
# Sales          500.0    1000.0  1498.0   1994.75   2500.0
# Discount         0.1      0.16    0.23      0.29     0.35
# Profit         25.25  180.0225  320.78  525.6275  1120.95
# State            NaN       NaN     NaN       NaN      NaN

# %% [markdown]
# #Analysis Data

# %% [markdown]
# #1)Sales Category & Sub Category

# %% [markdown]
# 1- Sales group by category

# %%
store.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Eggs, Meat & Fish    2267401
# Snacks               2237546
# Food Grains          2115272
# Bakery               2112281
# Fruits & Veggies     2100727
# Beverages            2085313
# Oil & Masala         2038442
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Category'])['Sales'].sum().reset_index()
#sns.barplot(x=cat_sales.index,y=cat_sales.values)

#for i, value in enumerate(cat_sales.values):
  #px.(i,value,f'{value:.2f}',ha='center',va='bottom')

fig=px.bar(cat_sales, x='Category', y='Sales', title=' Sales by Category', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6955c21f-28fd-45ab-b8ea-497bc26683ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6955c21f-28fd-45ab-b8ea-497bc26683ec")) {                    Plotly.newPlot(                        "6955c21f-28fd-45ab-b8ea-497bc26683ec",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[2112281.0,2085313.0,2267401.0,2115272.0,2100727.0,2038442.0,2237546.0],"textposition":"auto","x":["Bakery","Beverages","Eggs, Meat & Fish","Food Grains","Fruits & Veggies","Oil & Masala","Snacks"],"xaxis":"x","y":[2112281,2085313,2267401,2115272,2100727,2038442,2237546],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...

# %% [markdown]
# 2- Sales group by sub category

# %%
store.groupby('Sub Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Sub Category
# Health Drinks         1051439
# Soft Drinks           1033874
# Cookies                768213
# Breads & Buns          742586
# Noodles                735435
# Chocolates             733898
# Masalas                697480
# Cakes                  685612
# Biscuits               684083
# Spices                 672876
# Edible Oil & Ghee      668086
# Mutton                 611200
# Eggs                   575156
# Fish                   560548
# Organic Staples        558929
# Fresh Fruits           551212
# Atta & Flour           534649
# Fresh Vegetables       525842
# Dals & Pulses          523371
# Chicken                520497
# Organic Vegetables     520271
# Organic Fruits         503402
# Rice                   498323
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Sub Category'])['Sales'].sum().reset_index()

fig=px.bar(cat_sales, x='Sub Category', y='Sales', title=' Sales by Sub Category', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21ea1ef9-e987-401a-8fc3-b5e97285a6b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21ea1ef9-e987-401a-8fc3-b5e97285a6b2")) {                    Plotly.newPlot(                        "21ea1ef9-e987-401a-8fc3-b5e97285a6b2",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[534649.0,684083.0,742586.0,685612.0,520497.0,733898.0,768213.0,523371.0,668086.0,575156.0,560548.0,551212.0,525842.0,1051439.0,697480.0,611200.0,735435.0,503402.0,558929.0,520271.0,498323.0,1033874.0,672876.0],"textposition":"auto","x":["Atta & Flour","Biscuits","Breads & Buns","Cakes","Chicken","Chocolates","Cookies","Dals & Pulses","Edible Oil & Ghee","Eggs","Fish","Fresh Fruits","Fresh Vegetables","Health Drinks","Masalas","Mutton","Noodles","Organic Fruits","Organic Staples","Organic Vegetables","Rice","Soft Drinks","Spices"],"xaxis":"x","y":[534649,684083,742586,685612,520497,733898,768213,523371,668086,575156,560548,551212,525842,1051439,697480,611200,735435,503402,558929,520271,498323,1033874,672876],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...

# %% [markdown]
# 3- Sales group by category & sub category

# %%
cat_sales=store.groupby(['Category', 'Sub Category'])['Sales'].sum().reset_index()

fig=px.bar(cat_sales, x='Category', y='Sales', color='Sub Category', title=' Sales by Category & Sub Category', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a8d0bfb9-6bb0-4118-8938-a640c23c6e50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8d0bfb9-6bb0-4118-8938-a640c23c6e50")) {                    Plotly.newPlot(                        "a8d0bfb9-6bb0-4118-8938-a640c23c6e50",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[684083.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[684083],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Breads & Buns\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breads & Buns","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Breads & Buns","offsetgroup":"Breads & Buns","orientation":"v","showlegend":true,"text":[742586.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[742586],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[685612.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[685612],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[1051439.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1051439],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[1033874.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1033874],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Chicken\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chicken","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Chicken","offsetgroup":"Chicken","orientation":"v","showlegend":true,"text":[520497.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[520497],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Eggs\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eggs","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Eggs","offsetgroup":"Eggs","orientation":"v","showlegend":true,"text":[575156.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[575156],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Fish\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fish","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Fish","offsetgroup":"Fish","orientation":"v","showlegend":true,"text":[560548.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[560548],"yaxis":"y","type":"bar"},{"alignmentgroup":"Tr ...

# %% [markdown]
# 4- Sales group by category Top 5

# %%
store.groupby(['Category'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# Category
# Eggs, Meat & Fish    2267401
# Snacks               2237546
# Food Grains          2115272
# Bakery               2112281
# Fruits & Veggies     2100727
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Category'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Category', y='Sales', title=' Sales by Category Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4758d609-bc6d-4630-80de-accef84ebfde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4758d609-bc6d-4630-80de-accef84ebfde")) {                    Plotly.newPlot(                        "4758d609-bc6d-4630-80de-accef84ebfde",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[2267401.0,2237546.0,2115272.0,2112281.0,2100727.0],"textposition":"auto","x":["Eggs, Meat & Fish","Snacks","Food Grains","Bakery","Fruits & Veggies"],"xaxis":"x","y":[2267401,2237546,2115272,2112281,2100727],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay" ...

# %% [markdown]
# 5- Sales group by sub category Top 5

# %%
store.groupby(['Sub Category'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# Sub Category
# Health Drinks    1051439
# Soft Drinks      1033874
# Cookies           768213
# Breads & Buns     742586
# Noodles           735435
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Sub Category'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Sub Category', y='Sales', title=' Sales by Sub Category Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0976d8c3-2f24-4738-ba9a-eeeb47333dc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0976d8c3-2f24-4738-ba9a-eeeb47333dc3")) {                    Plotly.newPlot(                        "0976d8c3-2f24-4738-ba9a-eeeb47333dc3",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1051439.0,1033874.0,768213.0,742586.0,735435.0],"textposition":"auto","x":["Health Drinks","Soft Drinks","Cookies","Breads & Buns","Noodles"],"xaxis":"x","y":[1051439,1033874,768213,742586,735435],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size" ...

# %% [markdown]
# 6- Sales group by category & sub category Top 5

# %%
store.groupby(['Category', 'Sub Category'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# Category   Sub Category
# Beverages  Health Drinks    1051439
#            Soft Drinks      1033874
# Snacks     Cookies           768213
# Bakery     Breads & Buns     742586
# Snacks     Noodles           735435
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Category', 'Sub Category'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Category', y='Sales', color='Sub Category', title=' Sales by Category & Sub Category Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c7e6f20-aa12-45c8-a4c5-277df2a80082" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c7e6f20-aa12-45c8-a4c5-277df2a80082")) {                    Plotly.newPlot(                        "3c7e6f20-aa12-45c8-a4c5-277df2a80082",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[1051439.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1051439],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[1033874.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1033874],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cookies\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cookies","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cookies","offsetgroup":"Cookies","orientation":"v","showlegend":true,"text":[768213.0],"textposition":"auto","x":["Snacks"],"xaxis":"x","y":[768213],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Breads & Buns\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breads & Buns","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Breads & Buns","offsetgroup":"Breads & Buns","orientation":"v","showlegend":true,"text":[742586.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[742586],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Noodles\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Noodles","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Noodles","offsetgroup":"Noodles","orientation":"v","showlegend":true,"text":[735435.0],"textposition":"auto","x":["Snacks"],"xaxis":"x","y":[735435],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":" ...

# %% [markdown]
# #2)Prtofit Category & Sub Category

# %% [markdown]
# 1- Profit group by category

# %%
store.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Snacks               568178.85
# Eggs, Meat & Fish    567357.22
# Fruits & Veggies     530400.38
# Food Grains          529162.64
# Bakery               528521.06
# Beverages            525605.76
# Oil & Masala         497895.29
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Category'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='Category', y='Profit', title=' Profit by Category', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8a34b07d-165c-4f9b-8384-9f56d15230d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a34b07d-165c-4f9b-8384-9f56d15230d2")) {                    Plotly.newPlot(                        "8a34b07d-165c-4f9b-8384-9f56d15230d2",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[528521.06,525605.76,567357.22,529162.64,530400.38,497895.29,568178.85],"textposition":"auto","x":["Bakery","Beverages","Eggs, Meat & Fish","Food Grains","Fruits & Veggies","Oil & Masala","Snacks"],"xaxis":"x","y":[528521.06,525605.76,567357.22,529162.64,530400.38,497895.29,568178.85],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"m ...

# %% [markdown]
# 2- Profit group by sub category

# %%
store.groupby('Sub Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub Category
# Health Drinks         267469.79
# Soft Drinks           258135.97
# Noodles               193685.81
# Breads & Buns         190764.98
# Cookies               190643.70
# Chocolates            183849.34
# Biscuits              169357.62
# Masalas               168999.11
# Edible Oil & Ghee     168593.58
# Cakes                 168398.46
# Spices                160302.60
# Mutton                151389.40
# Fish                  147248.01
# Eggs                  144669.92
# Organic Staples       144136.89
# Fresh Fruits          134668.35
# Organic Vegetables    133596.37
# Fresh Vegetables      131273.33
# Organic Fruits        130862.33
# Dals & Pulses         130232.29
# Atta & Flour          127861.10
# Rice                  126932.36
# Chicken               124049.89
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Sub Category'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='Sub Category', y='Profit', title=' Profit by Sub Category', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e0dd7d87-5afd-4e58-a179-1ff844412db6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0dd7d87-5afd-4e58-a179-1ff844412db6")) {                    Plotly.newPlot(                        "e0dd7d87-5afd-4e58-a179-1ff844412db6",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[127861.1,169357.62,190764.98,168398.46,124049.89,183849.34,190643.7,130232.29,168593.58,144669.92,147248.01,134668.35,131273.33,267469.79,168999.11,151389.4,193685.81,130862.33,144136.89,133596.37,126932.36,258135.97,160302.6],"textposition":"auto","x":["Atta & Flour","Biscuits","Breads & Buns","Cakes","Chicken","Chocolates","Cookies","Dals & Pulses","Edible Oil & Ghee","Eggs","Fish","Fresh Fruits","Fresh Vegetables","Health Drinks","Masalas","Mutton","Noodles","Organic Fruits","Organic Staples","Organic Vegetables","Rice","Soft Drinks","Spices"],"xaxis":"x","y":[127861.1,169357.62,190764.98,168398.46,124049.89,183849.34,190643.7,130232.29,168593.58,144669.92,147248.01,134668.35,131273.33,267469.79,168999.11,151389.4,193685.81,130862.33,144136.89,133596.37,126932.36,258135.97,160302.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# 3- Profit group by category & sub category

# %%
cat_sales=store.groupby(['Category', 'Sub Category'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='Category', y='Profit', color='Sub Category', title=' Profit by Category & Sub Category', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6db2c18f-cbb1-4699-82a7-13087210fd72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6db2c18f-cbb1-4699-82a7-13087210fd72")) {                    Plotly.newPlot(                        "6db2c18f-cbb1-4699-82a7-13087210fd72",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[684083.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[684083],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Breads & Buns\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breads & Buns","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Breads & Buns","offsetgroup":"Breads & Buns","orientation":"v","showlegend":true,"text":[742586.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[742586],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[685612.0],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[685612],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[1051439.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1051439],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[1033874.0],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[1033874],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Chicken\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chicken","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Chicken","offsetgroup":"Chicken","orientation":"v","showlegend":true,"text":[520497.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[520497],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Eggs\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eggs","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Eggs","offsetgroup":"Eggs","orientation":"v","showlegend":true,"text":[575156.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[575156],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Fish\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fish","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Fish","offsetgroup":"Fish","orientation":"v","showlegend":true,"text":[560548.0],"textposition":"auto","x":["Eggs, Meat & Fish"],"xaxis":"x","y":[560548],"yaxis":"y","type":"bar"},{"alignmentgroup":"Tr ...

# %% [markdown]
# 4- Profit group by category Top 5

# %%
store.groupby(['Category'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Category
# Snacks               568178.85
# Eggs, Meat & Fish    567357.22
# Fruits & Veggies     530400.38
# Food Grains          529162.64
# Bakery               528521.06
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Category'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Category', y='Profit', title=' Profit by Category Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43594629-0faa-42c9-bad8-826a53e1e9d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43594629-0faa-42c9-bad8-826a53e1e9d4")) {                    Plotly.newPlot(                        "43594629-0faa-42c9-bad8-826a53e1e9d4",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[568178.85,567357.22,530400.38,529162.64,528521.06],"textposition":"auto","x":["Snacks","Eggs, Meat & Fish","Fruits & Veggies","Food Grains","Bakery"],"xaxis":"x","y":[568178.85,567357.22,530400.38,529162.64,528521.06],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode ...

# %% [markdown]
# 5- Profit group by sub category Top 5

# %%
store.groupby(['Sub Category'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Sub Category
# Health Drinks    267469.79
# Soft Drinks      258135.97
# Noodles          193685.81
# Breads & Buns    190764.98
# Cookies          190643.70
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Sub Category'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Sub Category', y='Profit', title=' Profit by Sub Category Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1c27c26c-b30c-49f9-ada8-04355cf04319" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c27c26c-b30c-49f9-ada8-04355cf04319")) {                    Plotly.newPlot(                        "1c27c26c-b30c-49f9-ada8-04355cf04319",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[267469.79,258135.97,193685.81,190764.98,190643.7],"textposition":"auto","x":["Health Drinks","Soft Drinks","Noodles","Breads & Buns","Cookies"],"xaxis":"x","y":[267469.79,258135.97,193685.81,190764.98,190643.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":" ...

# %% [markdown]
# 6- Profit group by category & sub category Top 5

# %%
store.groupby(['Category', 'Sub Category'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Category   Sub Category
# Beverages  Health Drinks    267469.79
#            Soft Drinks      258135.97
# Snacks     Noodles          193685.81
# Bakery     Breads & Buns    190764.98
# Snacks     Cookies          190643.70
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Category', 'Sub Category'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Category', y='Profit', color='Sub Category', title=' Profit by Category & Sub Category Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e016ed0-3834-4db7-90dd-da82f706b817" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e016ed0-3834-4db7-90dd-da82f706b817")) {                    Plotly.newPlot(                        "0e016ed0-3834-4db7-90dd-da82f706b817",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[267469.79],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[267469.79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCategory=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[258135.97],"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[258135.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Noodles\u003cbr\u003eCategory=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Noodles","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Noodles","offsetgroup":"Noodles","orientation":"v","showlegend":true,"text":[193685.81],"textposition":"auto","x":["Snacks"],"xaxis":"x","y":[193685.81],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Breads & Buns\u003cbr\u003eCategory=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breads & Buns","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Breads & Buns","offsetgroup":"Breads & Buns","orientation":"v","showlegend":true,"text":[190764.98],"textposition":"auto","x":["Bakery"],"xaxis":"x","y":[190764.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cookies\u003cbr\u003eCategory=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cookies","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cookies","offsetgroup":"Cookies","orientation":"v","showlegend":true,"text":[190643.7],"textposition":"auto","x":["Snacks"],"xaxis":"x","y":[190643.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"he ...

# %% [markdown]
# #3)Sales City & Region

# %% [markdown]
# 1- Sales group by City

# %%
store.groupby('City')['Sales'].sum().sort_values(ascending=False)
# Out:
# City
# Kanyakumari       706764
# Vellore           676550
# Bodi              667177
# Tirunelveli       659812
# Perambalur        659738
# Salem             657093
# Pudukottai        653179
# Tenkasi           643652
# Karur             642273
# Krishnagiri       637273
# Chennai           634963
# Coimbatore        634748
# Ramanadhapuram    634386
# Cumbum            626047
# Madurai           617836
# Virudhunagar      606820
# Ooty              599292
# Namakkal          598530
# Viluppuram        581274
# Theni             579553
# Dindigul          575631
# Dharmapuri        571553
# Nagercoil         551435
# Trichy            541403
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['City'])['Sales'].sum().reset_index()

fig=px.bar(cat_sales, x='City', y='Sales', title=' Sales by City', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd58787b-8764-496c-ba28-ab95d9ac7ddd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd58787b-8764-496c-ba28-ab95d9ac7ddd")) {                    Plotly.newPlot(                        "cd58787b-8764-496c-ba28-ab95d9ac7ddd",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[667177.0,634963.0,634748.0,626047.0,571553.0,575631.0,706764.0,642273.0,637273.0,617836.0,551435.0,598530.0,599292.0,659738.0,653179.0,634386.0,657093.0,643652.0,579553.0,659812.0,541403.0,676550.0,581274.0,606820.0],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[667177,634963,634748,626047,571553,575631,706764,642273,637273,617836,551435,598530,599292,659738,653179,634386,657093,643652,579553,659812,541403,676550,581274,606820],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh ...

# %% [markdown]
# 2- Sales group by Region

# %%
store.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       4798743
# East       4248368
# Central    3468156
# South      2440461
# North         1254
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Region'])['Sales'].sum().reset_index()

fig=px.bar(cat_sales, x='Region', y='Sales', title=' Sales by Region', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="04d801e8-4465-4772-8311-64a786fc7341" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04d801e8-4465-4772-8311-64a786fc7341")) {                    Plotly.newPlot(                        "04d801e8-4465-4772-8311-64a786fc7341",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3468156.0,4248368.0,1254.0,2440461.0,4798743.0],"textposition":"auto","x":["Central","East","North","South","West"],"xaxis":"x","y":[3468156,4248368,1254,2440461,4798743],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar ...

# %% [markdown]
# 3- Sales group by City & Region

# %%
cat_sales=store.groupby(['City', 'Region'])['Sales'].sum().reset_index()

fig=px.bar(cat_sales, x='City', y='Sales', color='Region', title=' Sales by City & Region', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c08b3a9-2246-4b19-8ff5-4395da213f21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c08b3a9-2246-4b19-8ff5-4395da213f21")) {                    Plotly.newPlot(                        "4c08b3a9-2246-4b19-8ff5-4395da213f21",                        [{"alignmentgroup":"True","hovertemplate":"Region=Central\u003cbr\u003eCity=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"text":[149663.0,152739.0,163379.0,120859.0,117005.0,157291.0,171409.0,143994.0,170683.0,154870.0,145804.0,146414.0,122100.0,142832.0,142595.0,147554.0,141730.0,134524.0,132504.0,152333.0,134443.0,165525.0,140820.0,117086.0],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[149663,152739,163379,120859,117005,157291,171409,143994,170683,154870,145804,146414,122100,142832,142595,147554,141730,134524,132504,152333,134443,165525,140820,117086],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCity=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"text":[173743.0,176938.0,166820.0,207283.0,153974.0,150801.0,209930.0,190776.0,177605.0,163914.0,142185.0,185645.0,189740.0,188977.0,201623.0,190077.0,217467.0,184627.0,142572.0,184674.0,128003.0,173322.0,169879.0,177793.0],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[173743,176938,166820,207283,153974,150801,209930,190776,177605,163914,142185,185645,189740,188977,201623,190077,217467,184627,142572,184674,128003,173322,169879,177793],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCity=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[95898.0,97947.0,117355.0,112364.0,80497.0,77935.0,121060.0,101378.0,111354.0,99908.0,90562.0,84846.0,119570.0,112030.0,113157.0,102025.0,98985.0,98800.0,108492.0,103313.0,87118.0,110832.0,89213.0,105822.0],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[95898,97947,117355,112364,80497,77935,121060,101378,111354,99908,90562,84846,119570,112030,113157,102025,98985,98800,108492,103313,87118,110832,89213,105822],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCity=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[247873.0,207339.0,187194.0,185541.0,220077.0,189604.0,204365.0,206125.0,1776 ...

# %% [markdown]
# 4- Sales group by City Top 5

# %%
store.groupby(['City'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# City
# Kanyakumari    706764
# Vellore        676550
# Bodi           667177
# Tirunelveli    659812
# Perambalur     659738
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['City'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='City', y='Sales', title=' Sales by City Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="03944451-799b-4c19-95b6-d7a20173301e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03944451-799b-4c19-95b6-d7a20173301e")) {                    Plotly.newPlot(                        "03944451-799b-4c19-95b6-d7a20173301e",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[706764.0,676550.0,667177.0,659812.0,659738.0],"textposition":"auto","x":["Kanyakumari","Vellore","Bodi","Tirunelveli","Perambalur"],"xaxis":"x","y":[706764,676550,667177,659812,659738],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}} ...

# %% [markdown]
# 5- Sales group by Region Top 5

# %%
store.groupby(['Region'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# Region
# West       4798743
# East       4248368
# Central    3468156
# South      2440461
# North         1254
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['Region'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Region', y='Sales', title=' Sales by Region Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6444e6c9-0ea7-4b80-ab75-ed582d663659" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6444e6c9-0ea7-4b80-ab75-ed582d663659")) {                    Plotly.newPlot(                        "6444e6c9-0ea7-4b80-ab75-ed582d663659",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[4798743.0,4248368.0,3468156.0,2440461.0,1254.0],"textposition":"auto","x":["West","East","Central","South","North"],"xaxis":"x","y":[4798743,4248368,3468156,2440461,1254],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar ...

# %% [markdown]
# 4- Sales group by City & Region Top 5

# %%
store.groupby(['City', 'Region'])['Sales'].sum().sort_values(ascending=False).head(5)
# Out:
# City         Region
# Bodi         West      247873
# Tenkasi      West      225701
# Vellore      West      225617
# Dharmapuri   West      220077
# Tirunelveli  West      219492
# Name: Sales, dtype: int64

# %%
cat_sales=store.groupby(['City', 'Region'])['Sales'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='City', y='Sales', color='Region', title=' Sales by City & Region Top 5', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75f62d3f-02f6-409c-a5fa-92c0bc6f583c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75f62d3f-02f6-409c-a5fa-92c0bc6f583c")) {                    Plotly.newPlot(                        "75f62d3f-02f6-409c-a5fa-92c0bc6f583c",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCity=%{x}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[247873.0,225701.0,225617.0,220077.0,219492.0],"textposition":"auto","x":["Bodi","Tenkasi","Vellore","Dharmapuri","Tirunelveli"],"xaxis":"x","y":[247873,225701,225617,220077,219492],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...

# %% [markdown]
# #4)Profit City & Region

# %% [markdown]
# 1- Profit group by City

# %%
store.groupby('City')['Profit'].sum().sort_values(ascending=False)
# Out:
# City
# Vellore           174073.01
# Bodi              173655.13
# Kanyakumari       172217.74
# Perambalur        171132.19
# Karur             169305.94
# Tirunelveli       165169.01
# Pudukottai        164072.63
# Chennai           160921.33
# Salem             160899.30
# Krishnagiri       160477.48
# Ramanadhapuram    158951.03
# Coimbatore        157399.41
# Cumbum            156355.13
# Tenkasi           156230.72
# Madurai           152548.61
# Virudhunagar      150816.69
# Ooty              150078.92
# Namakkal          145502.10
# Dindigul          144872.95
# Viluppuram        144200.64
# Theni             142739.78
# Dharmapuri        141593.05
# Nagercoil         137848.47
# Trichy            136059.94
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['City'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='City', y='Profit', title=' Profit by City', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6b12eb3c-7033-47f0-80f3-0d76617f1072" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b12eb3c-7033-47f0-80f3-0d76617f1072")) {                    Plotly.newPlot(                        "6b12eb3c-7033-47f0-80f3-0d76617f1072",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[173655.13,160921.33,157399.41,156355.13,141593.05,144872.95,172217.74,169305.94,160477.48,152548.61,137848.47,145502.1,150078.92,171132.19,164072.63,158951.03,160899.3,156230.72,142739.78,165169.01,136059.94,174073.01,144200.64,150816.69],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[173655.13,160921.33,157399.41,156355.13,141593.05,144872.95,172217.74,169305.94,160477.48,152548.61,137848.47,145502.1,150078.92,171132.19,164072.63,158951.03,160899.3,156230.72,142739.78,165169.01,136059.94,174073.01,144200.64,150816.69],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed ...

# %% [markdown]
# 2- Profit group by Region

# %%
store.groupby('Region')['Profit'].sum().sort_values(ascending=False)
# Out:
# Region
# West       1192004.61
# East       1074345.58
# Central     856806.84
# South       623562.89
# North          401.28
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Region'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='Region', y='Profit', title=' Profit by Region', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="31c758a0-3012-485a-a322-30e0ed31740b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31c758a0-3012-485a-a322-30e0ed31740b")) {                    Plotly.newPlot(                        "31c758a0-3012-485a-a322-30e0ed31740b",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[856806.84,1074345.58,401.28,623562.89,1192004.61],"textposition":"auto","x":["Central","East","North","South","West"],"xaxis":"x","y":[856806.84,1074345.58,401.28,623562.89,1192004.61],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %% [markdown]
# 3- Profit group by City & Region

# %%
cat_sales=store.groupby(['City', 'Region'])['Profit'].sum().reset_index()

fig=px.bar(cat_sales, x='City', y='Profit', color='Region', title=' Profit by City & Region', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c91de027-77f9-43ea-a1b0-90a7a63f8a99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c91de027-77f9-43ea-a1b0-90a7a63f8a99")) {                    Plotly.newPlot(                        "c91de027-77f9-43ea-a1b0-90a7a63f8a99",                        [{"alignmentgroup":"True","hovertemplate":"Region=Central\u003cbr\u003eCity=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"text":[40498.29,38443.14,41405.78,30310.23,28086.36,37532.06,36634.89,39330.24,41370.43,34830.92,37221.42,32847.96,30403.0,36888.75,31597.68,40042.01,35873.6,32114.54,32048.3,36575.97,36371.07,42205.21,33252.29,30922.7],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[40498.29,38443.14,41405.78,30310.23,28086.36,37532.06,36634.89,39330.24,41370.43,34830.92,37221.42,32847.96,30403.0,36888.75,31597.68,40042.01,35873.6,32114.54,32048.3,36575.97,36371.07,42205.21,33252.29,30922.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCity=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"text":[41629.96,47039.2,42942.56,52178.3,39077.83,41153.21,52988.09,49262.19,43710.1,38630.28,35462.73,48136.71,49375.52,48748.05,51758.51,50820.9,49174.49,43329.72,36079.27,47672.87,29982.51,48584.77,44341.57,42266.24],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[41629.96,47039.2,42942.56,52178.3,39077.83,41153.21,52988.09,49262.19,43710.1,38630.28,35462.73,48136.71,49375.52,48748.05,51758.51,50820.9,49174.49,43329.72,36079.27,47672.87,29982.51,48584.77,44341.57,42266.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCity=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[26002.52,23757.77,29617.32,30811.84,19129.76,18596.59,32194.87,28293.4,31189.21,24490.63,23216.64,21279.77,29318.07,29460.19,29395.42,23452.93,26639.6,25626.25,27297.47,26856.54,22758.34,27364.35,20374.31,26439.1],"textposition":"auto","x":["Bodi","Chennai","Coimbatore","Cumbum","Dharmapuri","Dindigul","Kanyakumari","Karur","Krishnagiri","Madurai","Nagercoil","Namakkal","Ooty","Perambalur","Pudukottai","Ramanadhapuram","Salem","Tenkasi","Theni","Tirunelveli","Trichy","Vellore","Viluppuram","Virudhunagar"],"xaxis":"x","y":[26002.52,23757.77,29617.32,30811.84,19129.76,18596.59,32194.87,28293.4,31189.21,24490.63,23216.64,21279.77,29318.07,29460.19,29395.42,23452.93,26639.6,25626.25,27297.47,26856.54,22758.34,27364.35,20374.31,26439.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCity=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name": ...

# %% [markdown]
# 4- Profit group by City Top 5

# %%
store.groupby(['City'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# City
# Vellore        174073.01
# Bodi           173655.13
# Kanyakumari    172217.74
# Perambalur     171132.19
# Karur          169305.94
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['City'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='City', y='Profit', title=' Profit by City Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d32edd20-8eed-4e23-b3a1-ace81c9c8427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d32edd20-8eed-4e23-b3a1-ace81c9c8427")) {                    Plotly.newPlot(                        "d32edd20-8eed-4e23-b3a1-ace81c9c8427",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[174073.01,173655.13,172217.74,171132.19,169305.94],"textposition":"auto","x":["Vellore","Bodi","Kanyakumari","Perambalur","Karur"],"xaxis":"x","y":[174073.01,173655.13,172217.74,171132.19,169305.94],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10," ...

# %% [markdown]
# 5- Profit group by Region Top 5

# %%
store.groupby(['Region'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# Region
# West       1192004.61
# East       1074345.58
# Central     856806.84
# South       623562.89
# North          401.28
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['Region'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='Region', y='Profit', title=' Profit by Region Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eca1c180-7b5b-4287-b19e-3550f2726b48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eca1c180-7b5b-4287-b19e-3550f2726b48")) {                    Plotly.newPlot(                        "eca1c180-7b5b-4287-b19e-3550f2726b48",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1192004.61,1074345.58,856806.84,623562.89,401.28],"textposition":"auto","x":["West","East","Central","South","North"],"xaxis":"x","y":[1192004.61,1074345.58,856806.84,623562.89,401.28],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %% [markdown]
# 4- Profit group by City & Region Top 5

# %%
store.groupby(['City', 'Region'])['Profit'].sum().sort_values(ascending=False).head(5)
# Out:
# City        Region
# Bodi        West      65524.36
# Perambalur  West      56035.20
# Vellore     West      55517.40
# Dharmapuri  West      55299.10
# Tenkasi     West      55160.21
# Name: Profit, dtype: float64

# %%
cat_sales=store.groupby(['City', 'Region'])['Profit'].sum().sort_values(ascending=False).head(5).reset_index()

fig=px.bar(cat_sales, x='City', y='Profit', color='Region', title=' Profit by City & Region Top 5', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="beb376fc-9ef6-4c89-8a96-937fb2ef4ecf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beb376fc-9ef6-4c89-8a96-937fb2ef4ecf")) {                    Plotly.newPlot(                        "beb376fc-9ef6-4c89-8a96-937fb2ef4ecf",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCity=%{x}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[65524.36,56035.2,55517.4,55299.1,55160.21],"textposition":"auto","x":["Bodi","Perambalur","Vellore","Dharmapuri","Tenkasi"],"xaxis":"x","y":[65524.36,56035.2,55517.4,55299.1,55160.21],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode": ...

# %% [markdown]
# #5)Catagory & Sub Category with City By Sales & Profit

# %% [markdown]
# 1- Category & Sub Category group by City with Sales

# %%
store.groupby(['City']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False)
# Out:
#                  Sales           Category        Sub Category
# City
# Kanyakumari     706764   Fruits & Veggies    Fresh Vegetables
# Vellore         676550       Oil & Masala             Masalas
# Bodi            667177          Beverages       Health Drinks
# Tirunelveli     659812             Bakery            Biscuits
# Perambalur      659738        Food Grains        Atta & Flour
# Salem           657093          Beverages         Soft Drinks
# Pudukottai      653179             Snacks             Noodles
# Tenkasi         643652  Eggs, Meat & Fish              Mutton
# Karur           642273             Snacks          Chocolates
# Krishnagiri     637273          Beverages       Health Drinks
# Chennai         634963             Bakery               Cakes
# Coimbatore      634748          Beverages       Health Drinks
# Ramanadhapuram  634386   Fruits & Veggies        Fresh Fruits
# Cumbum          626047  Eggs, Meat & Fish             Chicken
# Madurai         617836       Oil & Masala             Masalas
# Virudhunagar    606820       Oil & Masala             Masalas
# Ooty            599292        Food Grains     Organic Staples
# Namakkal        598530  Eggs, Meat & Fish                Eggs
# Viluppuram      581274             Bakery            Biscuits
# Theni           579553             Bakery               Cakes
# Dindigul        575631             Snacks             Cookies
# Dharmapuri      571553   Fruits & Veggies    Fresh Vegetables
# Nagercoil       551435   Fruits & Veggies  Organic Vegetables
# Trichy          541403   Fruits & Veggies    Fresh Vegetables

# %%
cat_sales=store.groupby(['City']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False).reset_index()

fig=px.bar(cat_sales, x='City', y='Category', color='Sub Category', title=' Category & Sub Category by City according to Sales', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96c59173-0765-434b-a16a-0e39a7f43912" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96c59173-0765-434b-a16a-0e39a7f43912")) {                    Plotly.newPlot(                        "96c59173-0765-434b-a16a-0e39a7f43912",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Fresh Vegetables\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fresh Vegetables","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fresh Vegetables","offsetgroup":"Fresh Vegetables","orientation":"v","showlegend":true,"text":[706764.0,571553.0,541403.0],"textposition":"auto","x":["Kanyakumari","Dharmapuri","Trichy"],"xaxis":"x","y":["Fruits & Veggies","Fruits & Veggies","Fruits & Veggies"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Masalas\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masalas","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Masalas","offsetgroup":"Masalas","orientation":"v","showlegend":true,"text":[676550.0,617836.0,606820.0],"textposition":"auto","x":["Vellore","Madurai","Virudhunagar"],"xaxis":"x","y":["Oil & Masala","Oil & Masala","Oil & Masala"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[667177.0,637273.0,634748.0],"textposition":"auto","x":["Bodi","Krishnagiri","Coimbatore"],"xaxis":"x","y":["Beverages","Beverages","Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[659812.0,581274.0],"textposition":"auto","x":["Tirunelveli","Viluppuram"],"xaxis":"x","y":["Bakery","Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Atta & Flour\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atta & Flour","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Atta & Flour","offsetgroup":"Atta & Flour","orientation":"v","showlegend":true,"text":[659738.0],"textposition":"auto","x":["Perambalur"],"xaxis":"x","y":["Food Grains"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[657093.0],"textposition":"auto","x":["Salem"],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Noodles\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Noodles","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Noodles","offsetgroup":"Noodles","orientation":"v","showlegend":true,"text":[653179.0],"textposition":"auto","x":["Pudukottai"]," ...

# %% [markdown]
# 2- Category & Sub Category group by City with Profit

# %%
store.groupby(['City']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False)
# Out:
#                    Profit           Category        Sub Category
# City
# Vellore         174073.01       Oil & Masala             Masalas
# Bodi            173655.13          Beverages       Health Drinks
# Kanyakumari     172217.74   Fruits & Veggies    Fresh Vegetables
# Perambalur      171132.19        Food Grains        Atta & Flour
# Karur           169305.94             Snacks          Chocolates
# Tirunelveli     165169.01             Bakery            Biscuits
# Pudukottai      164072.63             Snacks             Noodles
# Chennai         160921.33             Bakery               Cakes
# Salem           160899.30          Beverages         Soft Drinks
# Krishnagiri     160477.48          Beverages       Health Drinks
# Ramanadhapuram  158951.03   Fruits & Veggies        Fresh Fruits
# Coimbatore      157399.41          Beverages       Health Drinks
# Cumbum          156355.13  Eggs, Meat & Fish             Chicken
# Tenkasi         156230.72  Eggs, Meat & Fish              Mutton
# Madurai         152548.61       Oil & Masala             Masalas
# Virudhunagar    150816.69       Oil & Masala             Masalas
# Ooty            150078.92        Food Grains     Organic Staples
# Namakkal        145502.10  Eggs, Meat & Fish                Eggs
# Dindigul        144872.95             Snacks             Cookies
# Viluppuram      144200.64             Bakery            Biscuits
# Theni           142739.78             Bakery               Cakes
# Dharmapuri      141593.05   Fruits & Veggies    Fresh Vegetables
# Nagercoil       137848.47   Fruits & Veggies  Organic Vegetables
# Trichy          136059.94   Fruits & Veggies    Fresh Vegetables

# %%
cat_sales=store.groupby(['City']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False).reset_index()

fig=px.bar(cat_sales, x='City', y='Category', color='Sub Category', title=' Category & Sub Category by City according to Profit', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3b6a5a8-adf0-4190-82bd-22eac2988cc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3b6a5a8-adf0-4190-82bd-22eac2988cc6")) {                    Plotly.newPlot(                        "a3b6a5a8-adf0-4190-82bd-22eac2988cc6",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Masalas\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masalas","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Masalas","offsetgroup":"Masalas","orientation":"v","showlegend":true,"text":[174073.01,152548.61,150816.69],"textposition":"auto","x":["Vellore","Madurai","Virudhunagar"],"xaxis":"x","y":["Oil & Masala","Oil & Masala","Oil & Masala"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[173655.13,160477.48,157399.41],"textposition":"auto","x":["Bodi","Krishnagiri","Coimbatore"],"xaxis":"x","y":["Beverages","Beverages","Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Fresh Vegetables\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fresh Vegetables","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fresh Vegetables","offsetgroup":"Fresh Vegetables","orientation":"v","showlegend":true,"text":[172217.74,141593.05,136059.94],"textposition":"auto","x":["Kanyakumari","Dharmapuri","Trichy"],"xaxis":"x","y":["Fruits & Veggies","Fruits & Veggies","Fruits & Veggies"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Atta & Flour\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atta & Flour","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Atta & Flour","offsetgroup":"Atta & Flour","orientation":"v","showlegend":true,"text":[171132.19],"textposition":"auto","x":["Perambalur"],"xaxis":"x","y":["Food Grains"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Chocolates\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chocolates","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Chocolates","offsetgroup":"Chocolates","orientation":"v","showlegend":true,"text":[169305.94],"textposition":"auto","x":["Karur"],"xaxis":"x","y":["Snacks"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[165169.01,144200.64],"textposition":"auto","x":["Tirunelveli","Viluppuram"],"xaxis":"x","y":["Bakery","Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Noodles\u003cbr\u003eCity=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Noodles","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Noodles","offsetgroup":"Noodles","orientation":"v","showlegend":true,"text":[164072.63],"textposition":"auto","x":[" ...

# %% [markdown]
# #6)Catagory & Sub Category with Customer with Sales & Profit

# %% [markdown]
# 1- Category & Sub Category group by City with Sales

# %%
store.groupby(['Customer Name']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False)
# Out:
#                 Sales           Category        Sub Category
# Customer Name
# Krithika       334361             Bakery               Cakes
# Amrish         333351             Bakery            Biscuits
# Verma          331665          Beverages         Soft Drinks
# Arutra         325720          Beverages       Health Drinks
# Vidya          321798   Fruits & Veggies  Organic Vegetables
# Vinne          319565        Food Grains        Atta & Flour
# Shah           318588       Oil & Masala             Masalas
# Suresh         315973   Fruits & Veggies  Organic Vegetables
# Adavan         315341        Food Grains     Organic Staples
# Surya          312645        Food Grains        Atta & Flour
# Muneer         311553             Snacks             Cookies
# Ridhesh        309639        Food Grains     Organic Staples
# Sudeep         309196  Eggs, Meat & Fish                Fish
# Sheeba         308720             Bakery       Breads & Buns
# Mathew         308376             Snacks             Noodles
# Akash          307488       Oil & Masala   Edible Oil & Ghee
# Hussain        307337        Food Grains        Atta & Flour
# Peer           307026   Fruits & Veggies    Fresh Vegetables
# James          305915          Beverages         Soft Drinks
# Ravi           305591          Beverages         Soft Drinks
# Veronica       301611          Beverages         Soft Drinks
# Amy            301558        Food Grains        Atta & Flour
# Aditi          299674       Oil & Masala             Masalas
# Yusuf          299361   Fruits & Veggies    Fresh Vegetables
# Veena          299160        Food Grains       Dals & Pulses
# Haseena        298924  Eggs, Meat & Fish              Mutton
# Roshan         298463       Oil & Masala             Masalas
# Komal          295671  Eggs, Meat & Fish                Fish
# Ram            295338   Fruits & Veggies        Fresh Fruits
# Alan           294397             Bakery               Cakes
# Harish         293839       Oil & Masala             Masalas
# Arvind         293802          Beverages         Soft Drinks
# Willams        293597   Fruits & Veggies  Organic Vegetables
# Jonas          293489   Fruits & Veggies    Fresh Vegetables
# Shree          292566          Beverages       Health Drinks
# Ramesh         292087       Oil & Masala   Edible Oil & Ghee
# Malik          290884          Beverages       Health Drinks
# Sharon         289486             Snacks             Cookies
# Sabeela        288230  Eggs, Meat & Fish                Eggs
# Sundar         287151  Eggs, Meat & Fish             Chicken
# Vince          284536  Eggs, Meat & Fish                Eggs
# Rumaiza        284534             Snacks          Chocolates
# Anu            283735       Oil & Masala             Masalas
# Esther         283656          Beverages         Soft Drinks
# Ganesh         278349             Snacks          Chocolates
# Sudha          273493          Beverages       Health Drinks
# Yadav          273162  Eggs, Meat & Fish                Eggs
# Jackson        271793   Fruits & Veggies    Fresh Vegetables
# Kumar          262623          Beverages       Health Drinks
# Hafiz          251965   Fruits & Veggies        Fresh Fruits

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False).reset_index()

fig=px.bar(cat_sales, x='Customer Name', y='Category', color='Sub Category', title=' Category & Sub Category by Customer Name according to Sales', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1cc082ec-7323-4fe5-a750-6be49dd776ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cc082ec-7323-4fe5-a750-6be49dd776ea")) {                    Plotly.newPlot(                        "1cc082ec-7323-4fe5-a750-6be49dd776ea",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[334361.0,294397.0],"textposition":"auto","x":["Krithika","Alan"],"xaxis":"x","y":["Bakery","Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[333351.0],"textposition":"auto","x":["Amrish"],"xaxis":"x","y":["Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[331665.0,305915.0,305591.0,301611.0,293802.0,283656.0],"textposition":"auto","x":["Verma","James","Ravi","Veronica","Arvind","Esther"],"xaxis":"x","y":["Beverages","Beverages","Beverages","Beverages","Beverages","Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[325720.0,292566.0,290884.0,273493.0,262623.0],"textposition":"auto","x":["Arutra","Shree","Malik","Sudha","Kumar"],"xaxis":"x","y":["Beverages","Beverages","Beverages","Beverages","Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Organic Vegetables\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organic Vegetables","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Organic Vegetables","offsetgroup":"Organic Vegetables","orientation":"v","showlegend":true,"text":[321798.0,315973.0,293597.0],"textposition":"auto","x":["Vidya","Suresh","Willams"],"xaxis":"x","y":["Fruits & Veggies","Fruits & Veggies","Fruits & Veggies"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Atta & Flour\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atta & Flour","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Atta & Flour","offsetgroup":"Atta & Flour","orientation":"v","showlegend":true,"text":[319565.0,312645.0,307337.0,301558.0],"textposition":"auto","x":["Vinne","Surya","Hussain","Amy"],"xaxis":"x","y":["Food Grains","Food Grains","Food Grains","Food Grains"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Masalas\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u00 ...

# %% [markdown]
# 2- Category & Sub Category group by Customer Name with Profit

# %%
store.groupby(['Customer Name']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False)
# Out:
#                  Profit           Category        Sub Category
# Customer Name
# Arutra         87572.40          Beverages       Health Drinks
# Vidya          86725.64   Fruits & Veggies  Organic Vegetables
# Krithika       85633.03             Bakery               Cakes
# Akash          82121.26       Oil & Masala   Edible Oil & Ghee
# Surya          80996.85        Food Grains        Atta & Flour
# Amrish         80191.89             Bakery            Biscuits
# Vinne          79873.12        Food Grains        Atta & Flour
# Amy            79159.94        Food Grains        Atta & Flour
# Harish         79107.83       Oil & Masala             Masalas
# Verma          79096.53          Beverages         Soft Drinks
# Mathew         78888.56             Snacks             Noodles
# Aditi          78439.05       Oil & Masala             Masalas
# Yusuf          78425.87   Fruits & Veggies    Fresh Vegetables
# Sheeba         78378.75             Bakery       Breads & Buns
# Adavan         78044.29        Food Grains     Organic Staples
# Suresh         77450.88   Fruits & Veggies  Organic Vegetables
# Ridhesh        77405.91        Food Grains     Organic Staples
# Peer           77305.49   Fruits & Veggies    Fresh Vegetables
# Veronica       76884.93          Beverages         Soft Drinks
# Ravi           76815.31          Beverages         Soft Drinks
# Muneer         76379.35             Snacks             Cookies
# Komal          76165.17  Eggs, Meat & Fish                Fish
# Sharon         76070.13             Snacks             Cookies
# Sudeep         75727.78  Eggs, Meat & Fish                Fish
# Rumaiza        75616.04             Snacks          Chocolates
# Alan           74410.23             Bakery               Cakes
# Veena          73953.52        Food Grains       Dals & Pulses
# Willams        73928.14   Fruits & Veggies  Organic Vegetables
# Shah           73786.22       Oil & Masala             Masalas
# Jonas          73497.19   Fruits & Veggies    Fresh Vegetables
# Roshan         73299.12       Oil & Masala             Masalas
# Haseena        73167.14  Eggs, Meat & Fish              Mutton
# Sabeela        72961.96  Eggs, Meat & Fish                Eggs
# Vince          72707.39  Eggs, Meat & Fish                Eggs
# Hussain        72354.97        Food Grains        Atta & Flour
# James          71926.88          Beverages         Soft Drinks
# Arvind         71767.23          Beverages         Soft Drinks
# Ramesh         71209.02       Oil & Masala   Edible Oil & Ghee
# Jackson        70268.59   Fruits & Veggies    Fresh Vegetables
# Yadav          70264.34  Eggs, Meat & Fish                Eggs
# Anu            70238.28       Oil & Masala             Masalas
# Esther         69588.12          Beverages         Soft Drinks
# Malik          68630.07          Beverages       Health Drinks
# Shree          68578.92          Beverages       Health Drinks
# Sundar         68228.75  Eggs, Meat & Fish             Chicken
# Sudha          68044.43          Beverages       Health Drinks
# Kumar          67731.85          Beverages       Health Drinks
# Ganesh         67094.89             Snacks          Chocolates
# Ram            66970.60   Fruits & Veggies        Fresh Fruits
# Hafiz          64037.35   Fruits & Veggies        Fresh Fruits

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False).reset_index()

fig=px.bar(cat_sales, x='Customer Name', y='Category', color='Sub Category', title=' Category & Sub Category by Customer Name according to Profit', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40c6e805-3fd0-4a6d-98e3-534e3e490c3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40c6e805-3fd0-4a6d-98e3-534e3e490c3d")) {                    Plotly.newPlot(                        "40c6e805-3fd0-4a6d-98e3-534e3e490c3d",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[87572.4,68630.07,68578.92,68044.43,67731.85],"textposition":"auto","x":["Arutra","Malik","Shree","Sudha","Kumar"],"xaxis":"x","y":["Beverages","Beverages","Beverages","Beverages","Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Organic Vegetables\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organic Vegetables","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Organic Vegetables","offsetgroup":"Organic Vegetables","orientation":"v","showlegend":true,"text":[86725.64,77450.88,73928.14],"textposition":"auto","x":["Vidya","Suresh","Willams"],"xaxis":"x","y":["Fruits & Veggies","Fruits & Veggies","Fruits & Veggies"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[85633.03,74410.23],"textposition":"auto","x":["Krithika","Alan"],"xaxis":"x","y":["Bakery","Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Edible Oil & Ghee\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Edible Oil & Ghee","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Edible Oil & Ghee","offsetgroup":"Edible Oil & Ghee","orientation":"v","showlegend":true,"text":[82121.26,71209.02],"textposition":"auto","x":["Akash","Ramesh"],"xaxis":"x","y":["Oil & Masala","Oil & Masala"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Atta & Flour\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atta & Flour","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Atta & Flour","offsetgroup":"Atta & Flour","orientation":"v","showlegend":true,"text":[80996.85,79873.12,79159.94,72354.97],"textposition":"auto","x":["Surya","Vinne","Amy","Hussain"],"xaxis":"x","y":["Food Grains","Food Grains","Food Grains","Food Grains"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[80191.89],"textposition":"auto","x":["Amrish"],"xaxis":"x","y":["Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Masalas\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masalas","marker":{"color":"#F ...

# %% [markdown]
# 3-Category & Sub Category group by Customer Name with Sales Top 5

# %%
store.groupby(['Customer Name']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False).reset_index().head(5)
# Out:
#   Customer Name   Sales          Category        Sub Category
# 0      Krithika  334361            Bakery               Cakes
# 1        Amrish  333351            Bakery            Biscuits
# 2         Verma  331665         Beverages         Soft Drinks
# 3        Arutra  325720         Beverages       Health Drinks
# 4         Vidya  321798  Fruits & Veggies  Organic Vegetables

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Sales': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Sales', ascending=False).reset_index().head(5)

fig=px.bar(cat_sales, x='Customer Name', y='Category', color='Sub Category', title=' Category & Sub Category by Customer Name according to Sales', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="19c36c9f-1a41-462e-932a-da866a0cff51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19c36c9f-1a41-462e-932a-da866a0cff51")) {                    Plotly.newPlot(                        "19c36c9f-1a41-462e-932a-da866a0cff51",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[334361.0],"textposition":"auto","x":["Krithika"],"xaxis":"x","y":["Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Biscuits\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biscuits","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Biscuits","offsetgroup":"Biscuits","orientation":"v","showlegend":true,"text":[333351.0],"textposition":"auto","x":["Amrish"],"xaxis":"x","y":["Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Soft Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soft Drinks","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Soft Drinks","offsetgroup":"Soft Drinks","orientation":"v","showlegend":true,"text":[331665.0],"textposition":"auto","x":["Verma"],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[325720.0],"textposition":"auto","x":["Arutra"],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Organic Vegetables\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organic Vegetables","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Organic Vegetables","offsetgroup":"Organic Vegetables","orientation":"v","showlegend":true,"text":[321798.0],"textposition":"auto","x":["Vidya"],"xaxis":"x","y":["Fruits & Veggies"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4 ...

# %% [markdown]
# 4-Category & Sub Category group by Customer Name with Profit Top 5

# %%
store.groupby(['Customer Name']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False).reset_index().head(5)
# Out:
#   Customer Name    Profit          Category        Sub Category
# 0        Arutra  87572.40         Beverages       Health Drinks
# 1         Vidya  86725.64  Fruits & Veggies  Organic Vegetables
# 2      Krithika  85633.03            Bakery               Cakes
# 3         Akash  82121.26      Oil & Masala   Edible Oil & Ghee
# 4         Surya  80996.85       Food Grains        Atta & Flour

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Profit': 'sum','Category': 'first', 'Sub Category': 'first'}).sort_values(by='Profit', ascending=False).reset_index().head(5)

fig=px.bar(cat_sales, x='Customer Name', y='Category', color='Sub Category', title=' Category & Sub Category by Customer Name according to Profit', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="13800c3a-f52a-4958-9044-437b5dcee5fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13800c3a-f52a-4958-9044-437b5dcee5fd")) {                    Plotly.newPlot(                        "13800c3a-f52a-4958-9044-437b5dcee5fd",                        [{"alignmentgroup":"True","hovertemplate":"Sub Category=Health Drinks\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health Drinks","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Health Drinks","offsetgroup":"Health Drinks","orientation":"v","showlegend":true,"text":[87572.4],"textposition":"auto","x":["Arutra"],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Organic Vegetables\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organic Vegetables","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Organic Vegetables","offsetgroup":"Organic Vegetables","orientation":"v","showlegend":true,"text":[86725.64],"textposition":"auto","x":["Vidya"],"xaxis":"x","y":["Fruits & Veggies"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Cakes\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cakes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cakes","offsetgroup":"Cakes","orientation":"v","showlegend":true,"text":[85633.03],"textposition":"auto","x":["Krithika"],"xaxis":"x","y":["Bakery"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Edible Oil & Ghee\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Edible Oil & Ghee","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Edible Oil & Ghee","offsetgroup":"Edible Oil & Ghee","orientation":"v","showlegend":true,"text":[82121.26],"textposition":"auto","x":["Akash"],"xaxis":"x","y":["Oil & Masala"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub Category=Atta & Flour\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCategory=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atta & Flour","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Atta & Flour","offsetgroup":"Atta & Flour","orientation":"v","showlegend":true,"text":[80996.85],"textposition":"auto","x":["Surya"],"xaxis":"x","y":["Food Grains"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222 ...

# %% [markdown]
# #7)City & Region with Customer Name By Sales & Profit

# %% [markdown]
# 1- City & Rigion group by Customer Name with Sales

# %%
store.groupby(['Customer Name']).agg({'Sales': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Sales', ascending=False)
# Out:
#                 Sales            City   Region
# Customer Name
# Krithika       334361         Chennai     West
# Amrish         333351     Krishnagiri  Central
# Verma          331665     Kanyakumari     West
# Arutra         325720            Bodi     West
# Vidya          321798         Vellore    South
# Vinne          319565         Madurai  Central
# Shah           318588     Kanyakumari     East
# Suresh         315973       Nagercoil  Central
# Adavan         315341      Dharmapuri     West
# Surya          312645     Kanyakumari     West
# Muneer         311553          Trichy     West
# Ridhesh        309639            Ooty    South
# Sudeep         309196      Dharmapuri     West
# Sheeba         308720      Perambalur  Central
# Mathew         308376         Vellore     East
# Akash          307488          Trichy     East
# Hussain        307337      Perambalur     West
# Peer           307026     Kanyakumari     West
# James          305915           Salem  Central
# Ravi           305591      Dharmapuri    South
# Veronica       301611     Krishnagiri     East
# Amy            301558            Bodi     West
# Aditi          299674     Tirunelveli     West
# Yusuf          299361         Madurai     East
# Veena          299160          Trichy     East
# Haseena        298924         Tenkasi     West
# Roshan         298463    Virudhunagar     East
# Komal          295671     Krishnagiri     East
# Ram            295338        Namakkal  Central
# Alan           294397      Dharmapuri  Central
# Harish         293839         Vellore    North
# Arvind         293802         Vellore    South
# Willams        293597  Ramanadhapuram  Central
# Jonas          293489          Trichy     West
# Shree          292566      Coimbatore     East
# Ramesh         292087     Krishnagiri  Central
# Malik          290884        Namakkal  Central
# Sharon         289486        Dindigul    South
# Sabeela        288230     Tirunelveli  Central
# Sundar         287151     Kanyakumari  Central
# Vince          284536         Madurai  Central
# Rumaiza        284534           Karur     East
# Anu            283735         Madurai     East
# Esther         283656           Salem  Central
# Ganesh         278349           Karur     West
# Sudha          273493     Krishnagiri    South
# Yadav          273162        Namakkal     West
# Jackson        271793      Dharmapuri    South
# Kumar          262623     Kanyakumari    South
# Hafiz          251965  Ramanadhapuram     West

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Sales': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Sales', ascending=False).reset_index()

fig=px.bar(cat_sales, x='Customer Name', y='City', color='Region', title=' City & Region by Customer Name according to Sales', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="18191869-e3a3-4bc6-9c1c-0ed6860b5651" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18191869-e3a3-4bc6-9c1c-0ed6860b5651")) {                    Plotly.newPlot(                        "18191869-e3a3-4bc6-9c1c-0ed6860b5651",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[334361.0,331665.0,325720.0,315341.0,312645.0,311553.0,309196.0,307337.0,307026.0,301558.0,299674.0,298924.0,293489.0,278349.0,273162.0,251965.0],"textposition":"auto","x":["Krithika","Verma","Arutra","Adavan","Surya","Muneer","Sudeep","Hussain","Peer","Amy","Aditi","Haseena","Jonas","Ganesh","Yadav","Hafiz"],"xaxis":"x","y":["Chennai","Kanyakumari","Bodi","Dharmapuri","Kanyakumari","Trichy","Dharmapuri","Perambalur","Kanyakumari","Bodi","Tirunelveli","Tenkasi","Trichy","Karur","Namakkal","Ramanadhapuram"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Central\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"text":[333351.0,319565.0,315973.0,308720.0,305915.0,295338.0,294397.0,293597.0,292087.0,290884.0,288230.0,287151.0,284536.0,283656.0],"textposition":"auto","x":["Amrish","Vinne","Suresh","Sheeba","James","Ram","Alan","Willams","Ramesh","Malik","Sabeela","Sundar","Vince","Esther"],"xaxis":"x","y":["Krishnagiri","Madurai","Nagercoil","Perambalur","Salem","Namakkal","Dharmapuri","Ramanadhapuram","Krishnagiri","Namakkal","Tirunelveli","Kanyakumari","Madurai","Salem"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[321798.0,309639.0,305591.0,293802.0,289486.0,273493.0,271793.0,262623.0],"textposition":"auto","x":["Vidya","Ridhesh","Ravi","Arvind","Sharon","Sudha","Jackson","Kumar"],"xaxis":"x","y":["Vellore","Ooty","Dharmapuri","Vellore","Dindigul","Krishnagiri","Dharmapuri","Kanyakumari"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"text":[318588.0,308376.0,307488.0,301611.0,299361.0,299160.0,298463.0,295671.0,292566.0,284534.0,283735.0],"textposition":"auto","x":["Shah","Mathew","Akash","Veronica","Yusuf","Veena","Roshan","Komal","Shree","Rumaiza","Anu"],"xaxis":"x","y":["Kanyakumari","Vellore","Trichy","Krishnagiri","Madurai","Trichy","Virudhunagar","Krishnagiri","Coimbatore","Karur","Madurai"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"text":[293839.0],"textposition":"auto","x":["Harish"],"xax ...

# %% [markdown]
# 2- City & Region group by Customer Name with Profit

# %%
store.groupby(['Customer Name']).agg({'Profit': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Profit', ascending=False)
# Out:
#                  Profit            City   Region
# Customer Name
# Arutra         87572.40            Bodi     West
# Vidya          86725.64         Vellore    South
# Krithika       85633.03         Chennai     West
# Akash          82121.26          Trichy     East
# Surya          80996.85     Kanyakumari     West
# Amrish         80191.89     Krishnagiri  Central
# Vinne          79873.12         Madurai  Central
# Amy            79159.94            Bodi     West
# Harish         79107.83         Vellore    North
# Verma          79096.53     Kanyakumari     West
# Mathew         78888.56         Vellore     East
# Aditi          78439.05     Tirunelveli     West
# Yusuf          78425.87         Madurai     East
# Sheeba         78378.75      Perambalur  Central
# Adavan         78044.29      Dharmapuri     West
# Suresh         77450.88       Nagercoil  Central
# Ridhesh        77405.91            Ooty    South
# Peer           77305.49     Kanyakumari     West
# Veronica       76884.93     Krishnagiri     East
# Ravi           76815.31      Dharmapuri    South
# Muneer         76379.35          Trichy     West
# Komal          76165.17     Krishnagiri     East
# Sharon         76070.13        Dindigul    South
# Sudeep         75727.78      Dharmapuri     West
# Rumaiza        75616.04           Karur     East
# Alan           74410.23      Dharmapuri  Central
# Veena          73953.52          Trichy     East
# Willams        73928.14  Ramanadhapuram  Central
# Shah           73786.22     Kanyakumari     East
# Jonas          73497.19          Trichy     West
# Roshan         73299.12    Virudhunagar     East
# Haseena        73167.14         Tenkasi     West
# Sabeela        72961.96     Tirunelveli  Central
# Vince          72707.39         Madurai  Central
# Hussain        72354.97      Perambalur     West
# James          71926.88           Salem  Central
# Arvind         71767.23         Vellore    South
# Ramesh         71209.02     Krishnagiri  Central
# Jackson        70268.59      Dharmapuri    South
# Yadav          70264.34        Namakkal     West
# Anu            70238.28         Madurai     East
# Esther         69588.12           Salem  Central
# Malik          68630.07        Namakkal  Central
# Shree          68578.92      Coimbatore     East
# Sundar         68228.75     Kanyakumari  Central
# Sudha          68044.43     Krishnagiri    South
# Kumar          67731.85     Kanyakumari    South
# Ganesh         67094.89           Karur     West
# Ram            66970.60        Namakkal  Central
# Hafiz          64037.35  Ramanadhapuram     West

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Profit': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Profit', ascending=False).reset_index()

fig=px.bar(cat_sales, x='Customer Name', y='City', color='Region', title=' City & Region by Customer Name Profit', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="04a0bfa3-d744-4464-8cc6-a90bfa57f556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04a0bfa3-d744-4464-8cc6-a90bfa57f556")) {                    Plotly.newPlot(                        "04a0bfa3-d744-4464-8cc6-a90bfa57f556",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[87572.4,85633.03,80996.85,79159.94,79096.53,78439.05,78044.29,77305.49,76379.35,75727.78,73497.19,73167.14,72354.97,70264.34,67094.89,64037.35],"textposition":"auto","x":["Arutra","Krithika","Surya","Amy","Verma","Aditi","Adavan","Peer","Muneer","Sudeep","Jonas","Haseena","Hussain","Yadav","Ganesh","Hafiz"],"xaxis":"x","y":["Bodi","Chennai","Kanyakumari","Bodi","Kanyakumari","Tirunelveli","Dharmapuri","Kanyakumari","Trichy","Dharmapuri","Trichy","Tenkasi","Perambalur","Namakkal","Karur","Ramanadhapuram"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[86725.64,77405.91,76815.31,76070.13,71767.23,70268.59,68044.43,67731.85],"textposition":"auto","x":["Vidya","Ridhesh","Ravi","Sharon","Arvind","Jackson","Sudha","Kumar"],"xaxis":"x","y":["Vellore","Ooty","Dharmapuri","Dindigul","Vellore","Dharmapuri","Krishnagiri","Kanyakumari"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"text":[82121.26,78888.56,78425.87,76884.93,76165.17,75616.04,73953.52,73786.22,73299.12,70238.28,68578.92],"textposition":"auto","x":["Akash","Mathew","Yusuf","Veronica","Komal","Rumaiza","Veena","Shah","Roshan","Anu","Shree"],"xaxis":"x","y":["Trichy","Vellore","Madurai","Krishnagiri","Krishnagiri","Karur","Trichy","Kanyakumari","Virudhunagar","Madurai","Coimbatore"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Central\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"text":[80191.89,79873.12,78378.75,77450.88,74410.23,73928.14,72961.96,72707.39,71926.88,71209.02,69588.12,68630.07,68228.75,66970.6],"textposition":"auto","x":["Amrish","Vinne","Sheeba","Suresh","Alan","Willams","Sabeela","Vince","James","Ramesh","Esther","Malik","Sundar","Ram"],"xaxis":"x","y":["Krishnagiri","Madurai","Perambalur","Nagercoil","Dharmapuri","Ramanadhapuram","Tirunelveli","Madurai","Salem","Krishnagiri","Salem","Namakkal","Kanyakumari","Namakkal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"text":[79107.83],"textposition":"auto","x":["Harish"]," ...

# %% [markdown]
# 3- City & Region group by Customer Name with Sales Top 5

# %%
store.groupby(['Customer Name']).agg({'Sales': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Sales', ascending=False).reset_index().head(5)
# Out:
#   Customer Name   Sales         City   Region
# 0      Krithika  334361      Chennai     West
# 1        Amrish  333351  Krishnagiri  Central
# 2         Verma  331665  Kanyakumari     West
# 3        Arutra  325720         Bodi     West
# 4         Vidya  321798      Vellore    South

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Sales': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Sales', ascending=False).reset_index().head(5)

fig=px.bar(cat_sales, x='Customer Name', y='City', color='Region', title=' City & Region by Customer Name Sales', text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bca5f4c7-09b3-4627-84f5-7d16be16d315" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bca5f4c7-09b3-4627-84f5-7d16be16d315")) {                    Plotly.newPlot(                        "bca5f4c7-09b3-4627-84f5-7d16be16d315",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[334361.0,331665.0,325720.0],"textposition":"auto","x":["Krithika","Verma","Arutra"],"xaxis":"x","y":["Chennai","Kanyakumari","Bodi"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Central\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"text":[333351.0],"textposition":"auto","x":["Amrish"],"xaxis":"x","y":["Krishnagiri"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eSales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[321798.0],"textposition":"auto","x":["Vidya"],"xaxis":"x","y":["Vellore"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %% [markdown]
# 4- City & Region group by Customer Name with Profit Top 5

# %%
store.groupby(['Customer Name']).agg({'Profit': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Profit', ascending=False).reset_index().head(5)
# Out:
#   Customer Name    Profit         City Region
# 0        Arutra  87572.40         Bodi   West
# 1         Vidya  86725.64      Vellore  South
# 2      Krithika  85633.03      Chennai   West
# 3         Akash  82121.26       Trichy   East
# 4         Surya  80996.85  Kanyakumari   West

# %%
cat_sales=store.groupby(['Customer Name']).agg({'Profit': 'sum','City': 'first', 'Region': 'first'}).sort_values(by='Profit', ascending=False).reset_index().head(5)

fig=px.bar(cat_sales, x='Customer Name', y='City', color='Region', title=' City & Region by Customer Name Profit', text='Profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b72cc256-60fd-480a-8cdf-6893994e886f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b72cc256-60fd-480a-8cdf-6893994e886f")) {                    Plotly.newPlot(                        "b72cc256-60fd-480a-8cdf-6893994e886f",                        [{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"text":[87572.4,85633.03,80996.85],"textposition":"auto","x":["Arutra","Krithika","Surya"],"xaxis":"x","y":["Bodi","Chennai","Kanyakumari"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"text":[86725.64],"textposition":"auto","x":["Vidya"],"xaxis":"x","y":["Vellore"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eCity=%{y}\u003cbr\u003eProfit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"text":[82121.26],"textposition":"auto","x":["Akash"],"xaxis":"x","y":["Trichy"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface ...
